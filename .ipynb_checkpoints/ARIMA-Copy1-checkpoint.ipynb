# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
path = 'AirPassengers.csv'
data = pd.read_csv(path)
data['Month'] = pd.to_datetime(data['Month'])
data.set_index('Month', inplace=True)
data.head(10)
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# 1949-06-01         135
# 1949-07-01         148
# 1949-08-01         148
# 1949-09-01         136
# 1949-10-01         119

# %%
len(data)
# Out:
# 144

# %%
plt.plot(data)

# %% [markdown]
# ## Augmented Dickey-Fuller test

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(data['Passengers'])
print(result)
# Out:
# (0.8153688792060472, 0.991880243437641, 13, 130, {'1%': -3.4816817173418295, '5%': -2.8840418343195267, '10%': -2.578770059171598}, 996.6929308390189)

# %%
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1]) 
print('Critical Values:') 
for key, value in result[4].items(): 
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: 0.815369
# p-value: 0.991880
# Critical Values:
# 	1%: -3.482
# 	5%: -2.884
# 	10%: -2.579

# %%
# Since p value is more than 0.05, the null hypothesis will be rejected and hence the time series is non stationary

# %% [markdown]
# ## Finding the value of the d parameter

# %% [markdown]
# ### 1st difference

# %%
diff_1 = data.copy()
diff_1['Diff_1'] = data['Passengers'].diff()
diff_1.head(10)
# Out:
#             Passengers  Diff_1
# Month
# 1949-01-01         112     NaN
# 1949-02-01         118     6.0
# 1949-03-01         132    14.0
# 1949-04-01         129    -3.0
# 1949-05-01         121    -8.0
# 1949-06-01         135    14.0
# 1949-07-01         148    13.0
# 1949-08-01         148     0.0
# 1949-09-01         136   -12.0
# 1949-10-01         119   -17.0

# %%
plt.plot(diff_1['Diff_1'])

# %%
diff_1.keys()
# Out:
# Index(['Passengers', 'Diff_1'], dtype='object')

# %%
diff_1.replace([np.inf, -np.inf], np.nan, inplace=True)
diff_1.dropna(inplace=True)
diff_1.head()
# Out:
#             Passengers  Diff_1
# Month
# 1949-02-01         118     6.0
# 1949-03-01         132    14.0
# 1949-04-01         129    -3.0
# 1949-05-01         121    -8.0
# 1949-06-01         135    14.0

# %%
result = adfuller(diff_1['Diff_1'])
print(result)
# Out:
# (-2.8292668241700056, 0.054213290283824704, 12, 130, {'1%': -3.4816817173418295, '5%': -2.8840418343195267, '10%': -2.578770059171598}, 988.5069317854084)

# %%
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1]) 
print('Critical Values:') 
for key, value in result[4].items(): 
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -2.829267
# p-value: 0.054213
# Critical Values:
# 	1%: -3.482
# 	5%: -2.884
# 	10%: -2.579

# %% [markdown]
# ### 2nd difference

# %%
diff_2 = diff_1.copy()
diff_2['Diff_2'] = diff_1['Diff_1'].diff()
diff_2.head(10)
# Out:
#             Passengers  Diff_1  Diff_2
# Month
# 1949-02-01         118     6.0     NaN
# 1949-03-01         132    14.0     8.0
# 1949-04-01         129    -3.0   -17.0
# 1949-05-01         121    -8.0    -5.0
# 1949-06-01         135    14.0    22.0
# 1949-07-01         148    13.0    -1.0
# 1949-08-01         148     0.0   -13.0
# 1949-09-01         136   -12.0   -12.0
# 1949-10-01         119   -17.0    -5.0
# 1949-11-01         104   -15.0     2.0

# %%
plt.plot(diff_2['Diff_2'])

# %%
diff_2.replace([np.inf, -np.inf], np.nan, inplace=True)
diff_2.dropna(inplace=True)
diff_2.head()
# Out:
#             Passengers  Diff_1  Diff_2
# Month
# 1949-03-01         132    14.0     8.0
# 1949-04-01         129    -3.0   -17.0
# 1949-05-01         121    -8.0    -5.0
# 1949-06-01         135    14.0    22.0
# 1949-07-01         148    13.0    -1.0

# %%
result = adfuller(diff_2['Diff_2'])
print(result)
# Out:
# (-16.384231542468495, 2.7328918500143186e-29, 11, 130, {'1%': -3.4816817173418295, '5%': -2.8840418343195267, '10%': -2.578770059171598}, 988.6020417275602)

# %%
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1]) 
print('Critical Values:') 
for key, value in result[4].items(): 
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -16.384232
# p-value: 0.000000
# Critical Values:
# 	1%: -3.482
# 	5%: -2.884
# 	10%: -2.579

# %%
# d value could be taken as 1 or 2 but 2 has alot of noise so we will go with 1

# %% [markdown]
# ### Finding the value of p

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(data.Passengers.diff().dropna())
plt.show()

# %%
# p-value = 1 since the first lag is significantly out of the limit

# %% [markdown]
# ## Finding the value of q

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(data.Passengers.diff().dropna())
plt.show()

# %%
# q-value = 2 since 2 of the lags are out of the significance limit

# %% [markdown]
# ## Building ARIMA model

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(data['Passengers'], order=(1, 2, 2))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Passengers   No. Observations:                  144
# Model:                 ARIMA(1, 2, 2)   Log Likelihood                -691.954
# Date:                Fri, 12 Jul 2024   AIC                           1391.908
# Time:                        20:45:52   BIC                           1403.732
# Sample:                    01-01-1949   HQIC                          1396.713
#                          - 12-01-1960
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4710      0.123     -3.839      0.000      -0.711      -0.230
# ma.L1         -0.1368     10.513     -0.013      0.990     -20.742      20.468
# ma.L2         -0.8630      9.071     -0.095      0.924     -18.641      16.915
# sigma2       965.2450   1.02e+04      0.095      0.924    -1.9e+04    2.09e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.18   Jarque-Bera (JB):                 2.12
# Prob(Q):                              0.67   Prob(JB):                         0.35
# Heteroskedasticity (H):               6.99   Skew:                            -0.22
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
from statsmodels.graphics.tsaplots import plot_predict
pred = model_fit.predict(start=0, end=len(data)-1, dynamic=False)
plt.plot(pred, color='red', label='Fitted')
plt.plot(data['Passengers'], label='Original')
plt.legend()

# %% [markdown]
# ### Predicting future values

# %%
forecast_steps = 10
forecast_pred = model_fit.forecast(steps=forcast_steps)
print(forecast_pred)
plt.plot(forecast_pred)
# Out:
# 1961-01-01    477.961018
# 1961-02-01    459.924349
# 1961-03-01    472.029088
# 1961-04-01    469.937931
# 1961-05-01    474.532708
# 1961-06-01    475.978568
# 1961-07-01    478.907493
# 1961-08-01    481.137930
# 1961-09-01    483.697338
# 1961-10-01    486.101808
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
last_date = data.index[-1]
forecast_dates = pd.date_range(start=last_date, periods=forecast_steps + 1, freq='M')[1:]
forecast_dates
# Out:
# DatetimeIndex(['1961-01-31', '1961-02-28', '1961-03-31', '1961-04-30',
#                '1961-05-31', '1961-06-30', '1961-07-31', '1961-08-31',
#                '1961-09-30', '1961-10-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
forecast_df = pd.DataFrame(forecast_pred.to_numpy(), index=forecast_dates, columns=['Forecast'])
forecast_df
# Out:
#               Forecast
# 1961-01-31  477.961018
# 1961-02-28  459.924349
# 1961-03-31  472.029088
# 1961-04-30  469.937931
# 1961-05-31  474.532708
# 1961-06-30  475.978568
# 1961-07-31  478.907493
# 1961-08-31  481.137930
# 1961-09-30  483.697338
# 1961-10-31  486.101808

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['Passengers'], label='Original Data')
plt.plot(forecast_df.index, forecast_df['Forecast'], color='red', label='Forecast')
plt.plot(data)
plt.title('Time Series Forecast')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.show()
