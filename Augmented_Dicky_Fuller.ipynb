# %% [markdown]
# ## Using a small time series

# %%
data = [3, 4, 4, 5, 6, 7, 6, 6, 7, 8, 9, 12, 10]

# %%
import matplotlib.pyplot as plt
plt.plot(data)

# %%
from statsmodels.tsa.stattools import adfuller

adfuller(data)
# Out:
# (-0.9753836234744063,
#  0.7621363564361013,
#  0,
#  12,
#  {'1%': -4.137829282407408,
#   '5%': -3.1549724074074077,
#   '10%': -2.7144769444444443},
#  31.2466098872313)

# %%
# Test statistic
# p-value - since the p-value is not less than 0.05 we fail to reject the null hypothesis - the series is non-stationary

# %% [markdown]
# ## Bigger time series

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller

# %%
file_path = "./Series_1.xlsx"
# Out:
# './Series_1.xlsx'

# %%
df = pd.read_excel(file_path)

# %%
df.head()
# Out:
#    Time     Value
# 0     1  0.000000
# 1     2 -0.090263
# 2     3  0.749995
# 3     4  1.247887
# 4     5  0.131282

# %%
plt.plot(df["Value"])

# %%
X = df["Value"].values
result = adfuller(X)
print(result)
print()
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
# Out:
# (-22.184930227348676, 0.0, 0, 9999, {'1%': -3.4310041633725734, '5%': -2.861829101294412, '10%': -2.566923883481157}, 28167.381318321917)
#
# ADF Statistic: -22.184930
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Reject Ho - Time Series is Stationary
